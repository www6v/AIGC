# %% [markdown]
# <a href="https://colab.research.google.com/github/www6v/huggingfaceLab/blob/main/HuggingFace_Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 88.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 29.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Conversational

# %%
from transformers import pipeline
from transformers import Conversation
chatbot = pipeline("conversational")
conversation = Conversation(
	"what is you name ？"
)
chatbot(conversation).generated_responses
# Out:
# No model was supplied, defaulted to microsoft/DialoGPT-medium and revision 8bada3b (https://huggingface.co/microsoft/DialoGPT-medium).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ["I'm not sure, but I think it's a reference to the movie The Big Lebowski."]

# %%
conversation = Conversation(
	"Can you recommend any book to learn Python?"
)
chatbot(conversation).generated_responses
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ['I would recommend the book Python by Andrew Ng.']

# %% [markdown]
# # Fill-Mask

# %%
from transformers import pipeline
r = pipeline("fill-mask")(
    "The best <mask> package is Matplotlib"
)

print(r)
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# # Named Entity Recognition

# %%
from transformers import pipeline
r = pipeline("ner")(
    "Hello, my name is Dan I live in France and I'm discovering the Huggingface library"
)

print(r)
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# # Token Classification

# %%
from transformers import pipeline
pipeline("token-classification")(
    "Hello, my name is Dan I live in France and I'm discovering the Huggingface library", aggregation_strategy="simple"
)
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# # Sentiment Analysis

# %%
from transformers import pipeline
reviews = [
    "i got brown switches, which is supposed to be semi quiet but its freakin loud asf, thats the only annoying thing about this keyboard",
]
sentiments = pipeline("sentiment-analysis",
                     model="j-hartmann/emotion-english-distilroberta-base"
                      )(reviews)
print(sentiments)
# Out:
# ...
# [{'label': 'sadness', 'score': 0.5087662935256958}]

# %% [markdown]
# # Text Classification

# %%
from transformers import pipeline
r = pipeline("ner")(
    "Hello, my name is Dan I live in France and I'm discovering the Huggingface library"
)

print(r)

# %% [markdown]
# # Zero-shot Classification

# %%
from transformers import pipeline
r = pipeline("zero-shot-classification")(
    "I'm having problems with my phone and need to get it fixed",
    candidate_labels = ["urgent","not urgent","phone","tablet","PC"]
)

print(r)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# {'sequence': "I'm having problems with my phone and need to get it fixed", 'labels': ['phone', 'urgent', 'not urgent', 'PC', 'tablet'], 'scores': [0.6873535513877869, 0.3010500967502594, 0.005372506100684404, 0.0033189363311976194, 0.0029049236327409744]}

# %% [markdown]
# # Question Answering

# %%
# question="Who invented Transfer Learning?"
question="when was transfer learning created?"
context="""Transfer learning (TL) is a technique in machine learning (ML) in which knowledge learned from a task is re-used in order to boost performance on a related task.[1] For example, for image classification, knowledge gained while learning to recognize cars could be applied when trying to recognize trucks. This topic is related to the psychological literature on transfer of learning, although practical ties between the two fields are limited. Reusing/transferring information from previously learned tasks to new tasks has the potential to significantly improve learning efficiency.[2] In 1976, Bozinovski and Fulgosi published a paper addressing transfer learning in neural network training.[3][4] The paper gives a mathematical and geometrical model of the topic. In 1981, a report considered the application of transfer learning to a dataset of images representing letters of computer terminals, experimentally demonstrating positive and negative transfer learning.[5]

In 1993, Pratt formulated the discriminability-based transfer (DBT) algorithm.[6]

In 1997, Pratt and Thrun guest-edited a special issue of Machine Learning devoted to transfer learning,[7] and by 1998, the field had advanced to include multi-task learning,[8] along with more formal theoretical foundations.[9] Learning to Learn,[10] edited by Thrun and Pratt, is a 1998 review of the subject.

Transfer learning has been applied in cognitive science. Pratt guest-edited an issue of Connection Science on reuse of neural networks through transfer in 1996.[11]

Ng said in his NIPS 2016 tutorial[12][13][14] that TL would become the next driver of machine learning commercial success after supervised learning.

In the 2020 paper "Rethinking Pre-Training and self-training",[15] Zoph et al. reported that pre-training can hurt accuracy, and advocate self-training instead."""
r=pipeline("question-answering")(
    question=question,
    context=context,
)
print(r)
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# {'score': 0.916750431060791, 'start': 1524, 'end': 1528, 'answer': '1996'}

# %% [markdown]
# # Table Question Answering

# %%
import pandas as pd
# question="How many stars does the transformers repository have?"
question="How many contributors are working?"
context=pd.DataFrame.from_dict({
    "Repository": ["Transformers", "Datasets", "Tokenizers"],
    "Stars": ["36542","4512","3934"],
    "Contributors": ["651", "77", "34"],
    "Programming language": ["Python","Python","Python,Rust,NodeJS"]
})
r=pipeline("table-question-answering",model="google/tapas-large-finetuned-wtq",)(
    query=question,
    table=context,
)
print(r)
# Out:
# {'answer': 'SUM > 651, 77, 34', 'coordinates': [(0, 2), (1, 2), (2, 2)], 'cells': ['651', '77', '34'], 'aggregator': 'SUM'}

# %% [markdown]
# # Text Generation

# %%
question = ("Hello DataFans! In this video we will talk about Huggingface!")

outputs = pipeline("text-generation",num_return_sequences=4,return_full_text=False)(question)
print(outputs)
# Out:
# No model was supplied, defaulted to gpt2 and revision 6c0e608 (https://huggingface.co/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': '\n\nWe will introduce some of your characters in this short project...\n\nNatsume Kakuya - Asura of Team Agon\n\nFumiyaki'}, {'generated_text': '\n\nWe will also make a list and invite guest people to make their predictions to the Hug! We are already looking at the biggest and smallest number of votes to the'}, {'generated_text': ' In this episode we discuss a feature called "A Simple Way of Compressing Your Web Pages." Why do we use this method or is that quite an obvious feature? The answer'}, {'generated_text': "\n\nHave you ever noticed that every guy's profile on a website is a fake? The first time I saw a profile with that information was during an interview, of course"}]

# %% [markdown]
# # Translation X to Y

# %%
from transformers import pipeline
# translation = pipeline("translation_fr_to_en",model="Helsinki-NLP/opus-mt-fr-en")("Je veux des aubergines sur ma pizza")
translation = pipeline("translation_fr_to_en", model="Helsinki-NLP/opus-mt-en-fr")("I want eggplant on my pizza")
print(translation)
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-aee2a9dc49de> in <cell line: 3>()
#       1 from transformers import pipeline
#       2 # translation = pipeline("translation_fr_to_en",model="Helsinki-NLP/opus-mt-fr-en")("Je veux des aubergines sur ma pizza")
# ----> 3 translation = pipeline("translation_fr_to_en", model="Helsinki-NLP/opus-mt-en-fr")("I want eggplant on my pizza")
#       4 print(translation)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     919                 tokenizer_kwargs.pop("torch_dtype", None)
#     920
# --> 921             tokenizer = AutoTokenizer.from_pretrained(
# ...

# %% [markdown]
# # Summarization

# %%
from transformers import pipeline

text = ("As @sinoroc suggested correct way of installing a package via pip is using separate process since pip may cause closing a thread or may require a restart of interpreter to load new installed package so this is the right way of using the API: subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'SomeProject']) but since Python allows to access internal API and you know what you're using the API for you may want to use internal API anyway eg. if you're building own GUI package manager with alternative resourcess like https://www.lfd.uci.edu/~gohlke/pythonlibs/")
translation = pipeline("summarization")(text)
print(translation)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Your max_length is set to 142, but your input_length is only 140. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=70)
# [{'summary_text': " As @sinoroc suggested correct way of installing a package via pip is using separate process since pip may cause closing a thread or may require a restart of interpreter to load new installed package . But since Python allows to access internal API and you know what you're using the API for you may want to use internal API anyway ."}]

# %% [markdown]
# # Text-to-text Generation

# %%
from transformers import pipeline

translation = pipeline("text2text-generation")("translate English to German:")
print(translation)
# Out:
# No model was supplied, defaulted to t5-base and revision 686f1db (https://huggingface.co/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5_fast.py:158: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# ...

# %% [markdown]
# # Image Classification

# %%
from transformers import pipeline
classes = pipeline("image-classification")("https://i.natgeofe.com/n/548467d8-c5f1-4551-9f58-6817a8d2c45e/NationalGeographic_2572187.jpg?")
print(classes)
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 5dca96d (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'score': 0.8330214619636536, 'label': 'Egyptian cat'}, {'score': 0.07606133818626404, 'label': 'tiger cat'}, {'score': 0.06403912603855133, 'label': 'tabby, tabby cat'}, {'score': 0.007772132754325867, 'label': 'lynx, catamount'}, {'score': 0.0029626137111335993, 'label': 'Siamese cat, Siamese'}]

# %% [markdown]
# # Zero-shot image class

# %%
from transformers import pipeline
classes = pipeline("zero-shot-image-classification")("https://i.natgeofe.com/n/548467d8-c5f1-4551-9f58-6817a8d2c45e/NationalGeographic_2572187.jpg",
  candidate_labels = [
      "dog running",
      "cat walking",
      "animal sleeping",
      "human feeding cat"
  ])
print(classes)
# Out:
# No model was supplied, defaulted to openai/clip-vit-base-patch32 and revision f4881ba (https://huggingface.co/openai/clip-vit-base-patch32).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# [{'score': 0.8467491865158081, 'label': 'cat walking'}, {'score': 0.14829106628894806, 'label': 'human feeding cat'}, {'score': 0.004353618249297142, 'label': 'animal sleeping'}, {'score': 0.0006060617743059993, 'label': 'dog running'}]

# %% [markdown]
# # Image segmentation

# %%
from transformers import pipeline
masks = pipeline("image-segmentation")("https://www.alleycat.org/wp-content/uploads/2019/03/FELV-cat.jpg")
image(masks)
# Out:
# No model was supplied, defaulted to facebook/detr-resnet-50-panoptic and revision fc15262 (https://huggingface.co/facebook/detr-resnet-50-panoptic).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-d30ead8e5b05> in <cell line: 2>()
#       1 from transformers import pipeline
# ----> 2 masks = pipeline("image-segmentation")("https://www.alleycat.org/wp-content/uploads/2019/03/FELV-cat.jpg")
#       3 image(masks)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     822     if isinstance(model, str) or framework is None:
# ...

# %% [markdown]
# # Image-to-text

# %%
from transformers import pipeline
r = pipeline("image-to-text")("https://www.alleycat.org/wp-content/uploads/2019/03/FELV-cat.jpg")
print(r[0]["generated_text"])
# Out:
# No model was supplied, defaulted to ydshieh/vit-gpt2-coco-en and revision 65636df (https://huggingface.co/ydshieh/vit-gpt2-coco-en).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# /usr/local/lib/python3.10/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1260: UserWarning: Using the model-agnostic default `max_length` (=20) to control thegeneration length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ...

# %% [markdown]
# # Depth Estimation

# %% [markdown]
# # Video Classification

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# # Audio Classification

# %% [markdown]
# # Automatic Speech ReCognition
